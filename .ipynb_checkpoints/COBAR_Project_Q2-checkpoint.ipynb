# %% [markdown]
# # COBAR Project
#
# Authors: Célia Benquet, Artur Jesslen & Léa Schmidt

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns

# %%
pd.set_option('mode.chained_assignment', None)
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

# %% [markdown]
# ## 1. Load the data

# %%
path_MDN = 'data/MDN/U3_f'
with open(path_MDN + '/MDN_U3_f_trackingData.pkl', 'rb') as f: 
    data_MDN = pickle.load(f)
    
path_SS = 'data/SS01540/U3_f'
with open(path_SS + '/SS01540_U3_f_trackingData.pkl', 'rb') as f: 
    data_SS = pickle.load(f)
    
path_PR = 'data/PR/U3_f'
with open(path_PR + '/PR_U3_f_trackingData.pkl', 'rb') as f: 
    data_PR = pickle.load(f)

# %%
data_MDN.head()
# Out:
# bodyparts                                                  Abdomen  \
# coords                                                           x
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110534 0   0      73.963676
#                                                   1      69.640472
#                                                   2      68.444038
#                                                   3      69.041893
#                                                   4      69.084061
#
# bodyparts                                                            \
# coords                                                            y
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110534 0   0      102.580986
#                                                   1       91.774025
#                                                   2       90.962181
#                                                   3       91.408577
#                                                   4       91.067574
#
# bodyparts                                               LFbodyCoxa             \
# coords                                                           x          y
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110534 0   0      68.130081  57.273956
#                                                   1      68.785461  44.428471
#                                                   2      69.432381  45.397675
#                                                   3      69.524467  45.782764
#                                                   4      70.101135  45.144413
#
# bodyparts                                                   LFclaw             \
# coords                                                           x          y
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110534 0   0      56.071884  27.408962
#                                                   1      60.780922  16.183773
#                                                   2      62.511345  19.955723
#                                                   3      63.562450  20.809357
#                                                   4      63.124241  20.050495
#
# bodyparts                                               LFfemurTibia  \
# coords                                                             x
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110534 0   0        61.252773
#                                                   1        60.886108
#                                                   2        59.218887
#                                                   3        59.986305
#                                                   4        60.585194
#
# bodyparts                                                           \
# coords                                                           y
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110534 0   0      50.340820
#                                                   1      36.126186
#                                                   2      38.603561
#                                                   3      39.225670
#                                                   4      38.117634
#
# bodyparts                                               LFtibiaTarsus  \
# coords                                                              x
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110534 0   0         60.942657
#                                                   1         64.123833
#                                                   2         64.151230
#                                                   3         64.860085
#                                                   4         64.715088
#
# bodyparts                                                           ...  \
# coords                                                           y  ...
# stimulation exp_stage replicate datetime      fly frame             ...
# p3-4        on1       1         200206_110534 0   0      40.194889  ...
#                                                   1      28.175720  ...
#                                                   2      32.503151  ...
#                                                   3      33.005932  ...
#                                                   4      32.537628  ...
#
# bodyparts                                                    Rwing  \
# coords                                                           x
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110534 0   0      79.925781
#                                                   1      72.445267
#                                                   2      72.291374
#                                                   3      72.859055
#                                                   4      72.812119
#
# bodyparts                                                            \
# coords                                                            y
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110534 0   0      119.869736
#                                                   1      112.011940
#                                                   2      113.652657
#                                                   3      113.724785
#                                                   4      113.277809
#
# bodyparts                                                   Thorax             \
# coords                                                           x          y
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110534 0   0      71.546936  64.874649
#                                                   1      70.802231  53.652916
#                                                   2      70.553360  54.131649
#                                                   3      71.815010  54.421799
#                                                   4      71.435341  53.902748
#
# bodyparts                                                    center  \
# coords                                                  orientation
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110534 0   0      350.151031
#                                                   1      339.613907
#                                                   2      339.605774
#                                                   3      338.990555
#                                                   4      339.843582
#
# bodyparts                                                              \
# coords                                                  orientation_n
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110534 0   0          0.000000
#                                                   1        349.462875
#                                                   2        349.454742
#                                                   3        348.839523
#                                                   4        349.692551
#
# bodyparts                                                                      \
# coords                                                         posx    posx_n
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110534 0   0      727.816577  0.000000
#                                                   1      727.324067  0.382083
#                                                   2      727.007187  0.477125
#                                                   3      726.690209  0.770262
#                                                   4      726.244045  1.299228
#
# bodyparts
# coords                                                         posy    posy_n
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110534 0   0      129.152787  0.000000
#                                                   1      128.549645  0.678498
#                                                   2      127.280039  1.983596
#                                                   3      127.167970  2.148233
#                                                   4      127.690488  1.709733
#
# [5 rows x 70 columns]

# %%
data_SS.head()
# Out:
# bodyparts                                                  Abdomen             \
# coords                                                           x          y
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110645 0   0      67.100021  93.758507
#                                                   1      68.479431  94.498413
#                                                   2      68.462341  93.471649
#                                                   3      67.922501  92.891617
#                                                   4      67.790977  93.322136
#
# bodyparts                                               LFbodyCoxa             \
# coords                                                           x          y
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110645 0   0      65.629051  45.373863
#                                                   1      66.682732  45.218552
#                                                   2      66.493820  44.260029
#                                                   3      65.734764  43.840744
#                                                   4      65.604797  43.563110
#
# bodyparts                                                   LFclaw             \
# coords                                                           x          y
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110645 0   0      52.873211  13.489688
#                                                   1      52.460300  13.051150
#                                                   2      51.982605  12.859521
#                                                   3      50.205418  12.965647
#                                                   4      50.946606  16.099878
#
# bodyparts                                               LFfemurTibia  \
# coords                                                             x
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110645 0   0        55.949085
#                                                   1        57.036797
#                                                   2        57.346359
#                                                   3        55.875118
#                                                   4        56.201073
#
# bodyparts                                                           \
# coords                                                           y
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110645 0   0      36.431656
#                                                   1      36.413532
#                                                   2      36.394089
#                                                   3      36.418751
#                                                   4      35.850674
#
# bodyparts                                               LFtibiaTarsus  \
# coords                                                              x
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110645 0   0         57.851021
#                                                   1         58.247894
#                                                   2         57.822842
#                                                   3         56.771000
#                                                   4         55.541519
#
# bodyparts                                                           ...  \
# coords                                                           y  ...
# stimulation exp_stage replicate datetime      fly frame             ...
# p3-4        on1       1         200206_110645 0   0      26.462406  ...
#                                                   1      25.994297  ...
#                                                   2      25.355232  ...
#                                                   3      26.332901  ...
#                                                   4      26.940365  ...
#
# bodyparts                                                    Rwing  \
# coords                                                           x
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110645 0   0      70.099213
#                                                   1      71.256912
#                                                   2      70.367889
#                                                   3      69.479042
#                                                   4      69.922272
#
# bodyparts                                                            \
# coords                                                            y
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110645 0   0      114.101875
#                                                   1      113.904861
#                                                   2      113.203613
#                                                   3      112.870117
#                                                   4      113.237648
#
# bodyparts                                                   Thorax             \
# coords                                                           x          y
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110645 0   0      68.825745  58.120457
#                                                   1      69.630661  57.280811
#                                                   2      69.410408  55.608627
#                                                   3      68.618759  55.821243
#                                                   4      68.915833  55.697369
#
# bodyparts                                                    center  \
# coords                                                  orientation
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110645 0   0      321.112579
#                                                   1      321.809341
#                                                   2      322.031006
#                                                   3      323.181244
#                                                   4      324.935242
#
# bodyparts                                                              \
# coords                                                  orientation_n
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110645 0   0          0.000000
#                                                   1          0.696762
#                                                   2          0.918427
#                                                   3          2.068665
#                                                   4          3.822662
#
# bodyparts                                                                      \
# coords                                                         posx    posx_n
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110645 0   0      173.576537  0.000000
#                                                   1      173.882096 -0.691160
#                                                   2      174.354939 -1.433919
#                                                   3      174.737084 -2.241384
#                                                   4      174.914229 -2.908883
#
# bodyparts
# coords                                                         posy    posy_n
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_110645 0   0      632.913554  0.000000
#                                                   1      632.191471  0.370228
#                                                   2      631.594605  0.537971
#                                                   3      630.782218  0.930410
#                                                   4      629.938607  1.475850
#
# [5 rows x 70 columns]

# %%
data_PR.head()
# Out:
# bodyparts                                                  Abdomen             \
# coords                                                           x          y
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_111841 0   0      65.130417  90.493896
#                                                   1      66.375816  90.760017
#                                                   2      65.309357  92.018471
#                                                   3      67.772903  90.956497
#                                                   4      67.753204  92.759872
#
# bodyparts                                               LFbodyCoxa             \
# coords                                                           x          y
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_111841 0   0      64.222015  43.907032
#                                                   1      64.573082  42.599487
#                                                   2      64.123672  42.832272
#                                                   3      65.114395  40.519859
#                                                   4      64.327911  42.834377
#
# bodyparts                                                   LFclaw             \
# coords                                                           x          y
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_111841 0   0      51.529564  17.939919
#                                                   1      52.280083  19.922297
#                                                   2      53.580856  20.896881
#                                                   3      54.188465  23.596764
#                                                   4      51.178555  16.598473
#
# bodyparts                                               LFfemurTibia  \
# coords                                                             x
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_111841 0   0        56.683697
#                                                   1        57.022461
#                                                   2        54.996189
#                                                   3        56.195023
#                                                   4        55.591553
#
# bodyparts                                                           \
# coords                                                           y
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_111841 0   0      38.423500
#                                                   1      40.183418
#                                                   2      37.892750
#                                                   3      38.804588
#                                                   4      39.678432
#
# bodyparts                                               LFtibiaTarsus  \
# coords                                                              x
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_111841 0   0         54.959164
#                                                   1         56.357086
#                                                   2         56.204136
#                                                   3         57.827789
#                                                   4         55.675694
#
# bodyparts                                                           ...  \
# coords                                                           y  ...
# stimulation exp_stage replicate datetime      fly frame             ...
# p3-4        on1       1         200206_111841 0   0      29.315775  ...
#                                                   1      31.600788  ...
#                                                   2      30.749628  ...
#                                                   3      31.110428  ...
#                                                   4      28.746899  ...
#
# bodyparts                                                    Rwing  \
# coords                                                           x
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_111841 0   0      67.759155
#                                                   1      69.427483
#                                                   2      68.173470
#                                                   3      71.070824
#                                                   4      70.007942
#
# bodyparts                                                            \
# coords                                                            y
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_111841 0   0      111.293945
#                                                   1      111.506798
#                                                   2      112.175903
#                                                   3      111.247948
#                                                   4      112.109718
#
# bodyparts                                                   Thorax             \
# coords                                                           x          y
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_111841 0   0      68.146217  55.225182
#                                                   1      68.113174  55.610916
#                                                   2      67.390266  56.012398
#                                                   3      68.414658  54.480415
#                                                   4      67.795731  54.739567
#
# bodyparts                                                    center  \
# coords                                                  orientation
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_111841 0   0      164.701324
#                                                   1      163.404282
#                                                   2      161.437424
#                                                   3      160.626068
#                                                   4      158.805634
#
# bodyparts                                                              \
# coords                                                  orientation_n
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_111841 0   0          0.000000
#                                                   1        358.702957
#                                                   2        356.736099
#                                                   3        355.924744
#                                                   4        354.104309
#
# bodyparts                                                                      \
# coords                                                         posx    posx_n
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_111841 0   0      605.511469  0.000000
#                                                   1      606.564058 -0.023037
#                                                   2      608.781580  0.926986
#                                                   3      611.567153  2.262551
#                                                   4      614.025891  3.367574
#
# bodyparts
# coords                                                         posy     posy_n
# stimulation exp_stage replicate datetime      fly frame
# p3-4        on1       1         200206_111841 0   0      659.999410   0.000000
#                                                   1      663.934686   4.073550
#                                                   2      668.440708   9.004989
#                                                   3      673.562155  14.679925
#                                                   4      678.362544  19.958946
#
# [5 rows x 70 columns]

# %% [markdown]
# ## Part III: A deep study of behaviors driven by activation of specific DNs

# %% [markdown]
# ### 2. Analysis using the DeepLabCut joint position
#
# #### a. MDN data-set

# %% [markdown]
# We will plot the kinematics over time of the six pretarsus (aka. claws) of the flies.

# %%
#copy of the data-set to be able to modify
data_joint = data_MDN.copy()
#remove index to access them 
data_joint = data_joint.reset_index()
data_joint.head()
# Out:
# bodyparts stimulation exp_stage replicate       datetime fly frame    Abdomen  \
# coords                                                                      x
# 0                p3-4       on1         1  200206_110534   0     0  73.963676
# 1                p3-4       on1         1  200206_110534   0     1  69.640472
# 2                p3-4       on1         1  200206_110534   0     2  68.444038
# 3                p3-4       on1         1  200206_110534   0     3  69.041893
# 4                p3-4       on1         1  200206_110534   0     4  69.084061
#
# bodyparts             LFbodyCoxa             ...      Rwing              \
# coords              y          x          y  ...          x           y
# 0          102.580986  68.130081  57.273956  ...  79.925781  119.869736
# 1           91.774025  68.785461  44.428471  ...  72.445267  112.011940
# 2           90.962181  69.432381  45.397675  ...  72.291374  113.652657
# 3           91.408577  69.524467  45.782764  ...  72.859055  113.724785
# 4           91.067574  70.101135  45.144413  ...  72.812119  113.277809
#
# bodyparts     Thorax                 center                            \
# coords             x          y orientation orientation_n        posx
# 0          71.546936  64.874649  350.151031      0.000000  727.816577
# 1          70.802231  53.652916  339.613907    349.462875  727.324067
# 2          70.553360  54.131649  339.605774    349.454742  727.007187
# 3          71.815010  54.421799  338.990555    348.839523  726.690209
# 4          71.435341  53.902748  339.843582    349.692551  726.244045
#
# bodyparts
# coords       posx_n        posy    posy_n
# 0          0.000000  129.152787  0.000000
# 1          0.382083  128.549645  0.678498
# 2          0.477125  127.280039  1.983596
# 3          0.770262  127.167970  2.148233
# 4          1.299228  127.690488  1.709733
#
# [5 rows x 76 columns]

# %%
def get_single_coord(claw, data_joint, stage1=None, stage2=None):
    """""
    get x and y coordonates for each flies
    """""
    
    data_claw=data_joint[['exp_stage','fly',claw]]
    
    #data_claw = data_claw[(data_claw['exp_stage']==stage1) or ((data_claw['exp_stage']==stage2))]
    
    data_claw_0 = data_claw[(data_claw['fly']==0)]
    x0 = data_claw_0[claw,'x']
    y0 = data_claw_0[claw,'y']

    data_claw_1 = data_claw[data_claw['fly']==1]
    x1 = data_claw_1[claw,'x']
    y1 = data_claw_1[claw,'y']

    data_claw_2 = data_claw[data_claw['fly']==2]
    x2 = data_claw_2[claw,'x']
    y2 = data_claw_2[claw,'y']

    return x0,y0,x1,y1,x2,y2

# %%
def display_claw(claw, data_joint, color, start, end): 
    """""
    claw = the current leg 
    start, end: to be able to plot displacement for a given window of time
    start = starting frame from 0 to 9590 
    end = ending frame from 0 to 9590
    for each fly, we get the coordonates using 'get_single_coord' 
    then plot displacement (x then y) for each fly for current leg 
    """""
    
    x0,y0,x1,y1,x2,y2 = get_single_coord(claw, data_joint)
    time = range(start, end)
    
    #x position 
    plt.subplot(231) 
    plt.plot(x0[start:end], time, color=color, label=claw, linewidth=0.7)
    plt.ylabel("time")
    plt.xlabel("x-position")
    plt.title("x-position for fly 0")
    plt.xlim((0,120))
    plt.legend()

    plt.subplot(232)
    plt.plot(x1[start:end], time, color=color, label=claw, linewidth=0.7)
    plt.ylabel("time")
    plt.xlabel("x-position")
    plt.title("x-position for fly 1")
    plt.xlim((0,120))
    plt.legend()

    plt.subplot(233)
    plt.plot(x2[start:end], time, color=color, label=claw, linewidth=0.7)
    plt.ylabel("time")
    plt.xlabel("x-position")
    plt.title("x-position for fly 2")
    plt.xlim((0,120))
    plt.legend()

    #y position 
    plt.subplot(234) 
    plt.plot(time, y0[start:end], color=color, label=claw, linewidth=0.7)
    plt.xlabel("time")
    plt.ylabel("y-position")
    plt.title("y-position for fly 0")
    plt.ylim((0,120))
    plt.legend()

    plt.subplot(235)
    plt.plot(time, y1[start:end], color=color, label=claw, linewidth=0.7)
    plt.xlabel("time")
    plt.ylabel("y-position")
    plt.title("y-position for fly 1")
    plt.ylim((0,120))
    plt.legend()

    plt.subplot(236)
    plt.plot(time, y2[start:end], color=color, label=claw, linewidth=0.7)
    plt.xlabel("time")
    plt.ylabel("y-position")
    plt.title("y-position for fly 2")
    plt.ylim((0,120))
    plt.legend()

# %%
#display displacement for the all set of experiments 
start=0
end=9590

plt.figure(figsize=(20, 10))

#left set of legs 
display_claw('LFclaw', data_joint, 'r', start,end)
display_claw('LMclaw', data_joint, 'g', start,end)
display_claw('LHclaw', data_joint, 'b', start,end)

#right set of legs 
display_claw('RFclaw', data_joint, 'c', start,end)
display_claw('RMclaw', data_joint, 'm', start,end)
display_claw('RHclaw', data_joint, 'y', start,end)

plt.show()

# %%
#display for an on-simulation 
#duration = 240 frames = 3sec 
start=0
end=240

plt.figure(figsize=(20, 10))

#left set of legs 
display_claw('LFclaw', data_joint, 'r', start,end)
display_claw('LMclaw', data_joint, 'g', start,end)
display_claw('LHclaw', data_joint, 'b', start,end)

#right set of legs 
display_claw('RFclaw', data_joint, 'c', start,end)
display_claw('RMclaw', data_joint, 'm', start,end)
display_claw('RHclaw', data_joint, 'y', start,end)

plt.show()

# %%
#plot for an off-simulation 
#duration = 800 frames = 10sec 
start=240
end=1040

plt.figure(figsize=(20, 10))

#left set of legs 
display_claw('LFclaw', data_joint, 'r', start,end)
display_claw('LMclaw', data_joint, 'g', start,end)
display_claw('LHclaw', data_joint, 'b', start,end)

#right set of legs 
display_claw('RFclaw', data_joint, 'c', start,end)
display_claw('RMclaw', data_joint, 'm', start,end)
display_claw('RHclaw', data_joint, 'y', start,end)

plt.show()

# %%
plt.plot(x0,y0,color='r', label='Fly 0')
plt.plot(x1,y1,color='b', label='Fly 1')
plt.plot(x2,y2,color='g', label='Fly 2')

plt.xlabel("x-position")
plt.ylabel("y-position")
plt.title("Position for left front leg")
plt.legend()
plt.grid()

# %%
#velocity 
lf_claw_0['LFclaw', 'dist'] = np.sqrt(lf_claw_0['LFclaw','x'].pow(2) + lf_claw_0['LFclaw','y'].pow(2))

# %%
lf_claw_0.head()

# %%
interval=1/80
lf_claw_0['LFclaw', 'speed'] = lf_claw_0['LFclaw', 'dist'] / interval

# %%
lf_claw_0

# %%
plt.plot(lf_claw_0['LFclaw', 'speed'],color='g', label='Fly 0')

plt.xlabel("time (sec)")
plt.ylabel("speed")
plt.title("Speed for left front leg")
plt.legend()
plt.grid()
